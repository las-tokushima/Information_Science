# %% [markdown]
# # 2-5 まとめ

# %%
# Titanic号乗客税損状況データ
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
titanic = sns.load_dataset('titanic')
cross_survive = pd.crosstab(titanic['pclass'], titanic['survived'], normalize='index')
cross_survive.plot.bar(stacked=True)
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
cross_survive=pd.crosstab(titanic['pclass'],titanic['survived'])

# %%
titanic.boxplot(column=['age'],by='pclass')
plt.ylabel('Age')
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
titanic.hist(bins=10,by='pclass',column='age',layout=(3,1),sharex=True)
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
# UKgasデータ ％matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df = pd.read_csv("UKgas.tsv",  sep=r"\s+", index_col='Year')
df = df.loc[1970:, :]
df = df.stack()
date_index = pd.date_range('1970-01-01', '1986-12-31', freq='QE')
df_time = pd.DataFrame(df.values, index=date_index, columns =['values'])
df_time.plot(marker='o',linestyle='')
# Out:
# <Axes: >

# %%
# Titanic号乗客税損状況データ ％
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
titanic = sns.load_dataset('titanic')
cross_survive=pd.crosstab(titanic['pclass'],titanic['survived'], normalize='index')
cross_survive.plot.bar(stacked=True)
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
df_time.plot(marker='o',linestyle='-')
# Out:
# <Axes: >

# %%
cross_survive = pd.crosstab(titanic['pclass'],titanic['survived'])
cross_survive.plot.bar()
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic.boxplot(column=['age'],by='pclass')
plt.ylabel('Age')
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
titanic.hist(bins=10,by='pclass',column='age',layout=(3,1),sharex=True)
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')
